# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
m= load_model('facedetect.h5')

# %%
from keras.preprocessing import image

# %%
timage= image.load_img('D:\\face\\test\\udit_test\\21.jpg',target_size=(224,224,3))

# %%
type(timage)
# Out:
# PIL.Image.Image

# %%
timage
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1258B4B6848>

# %%
timage= image.img_to_array(timage)

# %%
import numpy as np

# %%
timg= np.expand_dims(timage,axis=0)

# %%
timg.shape
# Out:
# (1, 224, 224, 3)

# %%
result= m.predict(timg)

# %%
result
# Out:
# array([[1.]], dtype=float32)
